# %% [markdown]
# # kagglepipe — branch `inspect`
# Generated 2026-06-04.
#
# Source dataset: `holamigohello/kagglepipe-inspect-src` v2.

# %%
import os, sys
src_mount = '/kaggle/input/datasets/holamigohello/kagglepipe-inspect-src'
sys.path.insert(0, os.path.join(src_mount, 'src'))
sys.path.insert(0, src_mount)
os.chdir(src_mount)
print('Source mounted at:', src_mount)

# %%
import os
out_dir = '/kaggle/working/features'
os.makedirs(out_dir, exist_ok=True)
print('Output dir:', out_dir)

# %%
data_mount = '/kaggle/input/datasets/holamigohello/sample-data'
print('Data mounted at:', data_mount)

# !PYTHONPATH=$PYTHONPATH:'/kaggle/input/datasets/holamigohello/kagglepipe-inspect-src'/src:'/kaggle/input/datasets/holamigohello/kagglepipe-inspect-src' python scripts/inspect.py --out-dir /kaggle/working/features

# %%
import os
out_dir = '/kaggle/working/features'
print('Files in out_dir:')
for f in sorted(os.listdir(out_dir)):
    full = os.path.join(out_dir, f)
    print(f'  {f}  ({os.path.getsize(full)} bytes)')
